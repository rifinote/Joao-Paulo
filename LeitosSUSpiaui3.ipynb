# %% [markdown]
# <a href="https://colab.research.google.com/github/rifinote/Joao-Paulo/blob/main/LeitosSUSpiaui3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/Leitos_CNES_PI_Completo_2016_2022.csv')

# %% [markdown]
# # **DATAFRAME**

# %%
df.head(10)
# Out:
#    Unnamed: 0 Competência   Ano  Mes  Código   Categoria          Descrição  \
# 0           0  2016-01-20  2016    1      33     Clinico      CLINICA GERAL
# 1           1  2016-01-20  2016    1      45  Pediatrico  PEDIATRIA CLINICA
# 2           2  2016-02-20  2016    2      33     Clinico      CLINICA GERAL
# 3           3  2016-02-20  2016    2      45  Pediatrico  PEDIATRIA CLINICA
# 4           4  2016-03-20  2016    3      33     Clinico      CLINICA GERAL
# 5           5  2016-03-20  2016    3      45  Pediatrico  PEDIATRIA CLINICA
# 6           6  2016-04-20  2016    4      33     Clinico      CLINICA GERAL
# 7           7  2016-04-20  2016    4      45  Pediatrico  PEDIATRIA CLINICA
# 8           8  2016-05-20  2016    5      33     Clinico      CLINICA GERAL
# 9           9  2016-05-20  2016    5      45  Pediatrico  PEDIATRIA CLINICA
#
#    Existente  SUS  %Ocupação  Geocodigo  População    País Estado  \
# ...

# %%
df.tail(10)
# Out:
#        Unnamed: 0          Competência   Ano  Mes  Código   Categoria  \
# 48562       48562  2022-10-20 00:00:00  2022   10      10  Obstetrico
# 48563       48563  2022-10-20 00:00:00  2022   10      45  Pediatrico
# 48564       48564  2022-11-20 00:00:00  2022   11       3   Cirurgico
# 48565       48565  2022-11-20 00:00:00  2022   11      33     Clinico
# 48566       48566  2022-11-20 00:00:00  2022   11      10  Obstetrico
# 48567       48567  2022-11-20 00:00:00  2022   11      45  Pediatrico
# 48568       48568  2022-12-20 00:00:00  2022   12       3   Cirurgico
# 48569       48569  2022-12-20 00:00:00  2022   12      33     Clinico
# 48570       48570  2022-12-20 00:00:00  2022   12      10  Obstetrico
# 48571       48571  2022-12-20 00:00:00  2022   12      45  Pediatrico
#
#                    Descrição  Existente  SUS  %Ocupação  Geocodigo  População  \
# 48562  OBSTETRICIA CIRURGICA          4    4        1.0     221170       4479
# ...

# %%
print(df.iloc[0])
# Out:
# Unnamed: 0                                0
# Competência                      2016-01-20
# Ano                                    2016
# Mes                                       1
# Código                                   33
# Categoria                           Clinico
# Descrição                     CLINICA GERAL
# Existente                                 8
# SUS                                       8
# %Ocupação                               1.0
# Geocodigo                            220010
# População                              5165
# País                                 Brasil
# Estado                                   PI
# Município                      Agricolândia
# Mesoregião           Centro-Norte Piauiense
# Regional de Saúde                Entre Rios
# Name: 0, dtype: object

# %%
print(df['Existente'])
# Out:
# 0        8
# 1        7
# 2        8
# 3        7
# 4        8
#         ..
# 48567    3
# 48568    8
# 48569    4
# 48570    4
# 48571    3
# Name: Existente, Length: 48572, dtype: int64

# %%
print(df.loc[2, 'Existente'])
# Out:
# 8

# %% [markdown]
# # **EXCLUINDO COLUNAS**

# %%
df = df.drop('Mes', axis=1)

# %%
df = df.drop('Código', axis=1)

# %%
df = df.drop('Descrição', axis=1)

# %%
df = df.drop('%Ocupação', axis=1)

# %%
df = df.drop('Geocodigo', axis=1)

# %%
df = df.drop('País', axis=1)

# %%
df = df.drop('Mesoregião', axis=1)

# %%
df = df.drop('Regional de Saúde', axis=1)

# %%
df = df.drop('Categoria', axis=1)

# %%
df
# Out:
#        Unnamed: 0          Competência   Ano  Existente  SUS  População  \
# 0               0           2016-01-20  2016          8    8       5165
# 1               1           2016-01-20  2016          7    7       5165
# 2               2           2016-02-20  2016          8    8       5165
# 3               3           2016-02-20  2016          7    7       5165
# 4               4           2016-03-20  2016          8    8       5165
# ...           ...                  ...   ...        ...  ...        ...
# 48567       48567  2022-11-20 00:00:00  2022          3    3       4479
# 48568       48568  2022-12-20 00:00:00  2022          8    8       4479
# 48569       48569  2022-12-20 00:00:00  2022          4    4       4479
# 48570       48570  2022-12-20 00:00:00  2022          4    4       4479
# 48571       48571  2022-12-20 00:00:00  2022          3    3       4479
#
#       Estado     Município
# 0         PI  Agricolândia
# 1         PI  Agricolândia
# ...

# %% [markdown]
# # **FILTRAGEM DO MUNICIPIO DE TERESINA**

# %%
df.query('Município=="Teresina"')
# Out:
#        Unnamed: 0          Competência   Ano  Existente  SUS  População  \
# 42253       42253  2016-01-20 00:00:00  2016         26    7     854589
# 42254       42254  2016-01-20 00:00:00  2016         47   35     854589
# 42255       42255  2016-01-20 00:00:00  2016        372  272     854589
# 42256       42256  2016-01-20 00:00:00  2016          4    2     854589
# 42257       42257  2016-01-20 00:00:00  2016         16    6     854589
# ...           ...                  ...   ...        ...  ...        ...
# 46744       46744  2022-12-20 00:00:00  2022         53   37     871126
# 46745       46745  2022-12-20 00:00:00  2022         42   37     871126
# 46746       46746  2022-12-20 00:00:00  2022         17   17     871126
# 46747       46747  2022-12-20 00:00:00  2022          3    3     871126
# 46748       46748  2022-12-20 00:00:00  2022          4    4     871126
#
#       Estado Município
# 42253     PI  Teresina
# 42254     PI  Teresina
# 42255     PI  Teresina
# ...

# %%
df.query("Ano == 2016")
# Out:
#        Unnamed: 0          Competência   Ano  Existente  SUS  População  \
# 0               0           2016-01-20  2016          8    8       5165
# 1               1           2016-01-20  2016          7    7       5165
# 2               2           2016-02-20  2016          8    8       5165
# 3               3           2016-02-20  2016          7    7       5165
# 4               4           2016-03-20  2016          8    8       5165
# ...           ...                  ...   ...        ...  ...        ...
# 48279       48279  2016-11-20 00:00:00  2016          3    3       4436
# 48280       48280  2016-12-20 00:00:00  2016          8    8       4436
# 48281       48281  2016-12-20 00:00:00  2016          4    4       4436
# 48282       48282  2016-12-20 00:00:00  2016          4    4       4436
# 48283       48283  2016-12-20 00:00:00  2016          3    3       4436
#
#       Estado     Município
# 0         PI  Agricolândia
# 1         PI  Agricolândia
# ...

# %% [markdown]
# # **SOMA DOS LEITOS POR DIA DE CADA ANO**

# %%
SomaDosDia = df.groupby('Ano', as_index = False) ['Existente'].sum()
SomaDosDia
# Out:
#     Ano  Existente
# 0  2016      94479
# 1  2017      97326
# 2  2018      97646
# 3  2019      97221
# 4  2020     105113
# 5  2021     109793
# 6  2022     105735
